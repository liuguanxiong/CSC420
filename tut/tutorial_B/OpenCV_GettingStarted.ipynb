# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive/"
# Out:
# BabakTaati__UWO_Dec14_2010.7z
# budgetting scheme.gsheet
# CavePainting.jpg
# CC-ABHI.docx
# CC-ABHI.docx.gdoc
# CC-ABHI Project Planning Template.xlsx
# chera najar nashodam - 1 (1).mp3
# chera najar nashodam - 1.mp3
# chera najar nashodam - 2 (1).mp3
# chera najar nashodam - 2.mp3
# Colab Notebooks
# CRV2010.7z
# CRV2010.zip
# eshtebeh e lopi - dar hozoor e shaer bozorg (1).mp3
# eshtebeh e lopi - dar hozoor e shaer bozorg.mp3
# FG2018 - Special Session - measurable social impact systems and applications.gdoc
# foo.txt
# for Mathworks.gdoc
# Functional Decline  AI - full proposal updated June 29 CC_AM_BT.gdoc
# Gerentechnology2010.zip
# gharigh1 (1).mp3
# gharigh1.mp3
# gharigh2 (1).mp3
# gharigh2.mp3
# Ideas.gdoc
# immigration letter.rar
# Interview questions.gdoc
# Joint TRI - VISTA workshop.gsheet
# LIDAR Images.zip
# marg e honarpisheh (1).mp3
# marg e honarpisheh.mp3
# Models.zip
# molaghat e 2 doost e ghadimi (1).mp3
# molaghat e 2 doost e ghadimi.mp3
# moorchegan (1).mp3
# moorchegan.mp3
# Movies to watch.gsheet
# My To-Do list.gsheet
# naleh ye zan dar del e shab (1).mp3
# naleh ye zan dar del e shab.mp3
# Notes.gdoc
# photo.JPG
# PRINTABLE_BoardingPass_Babak_Taati_PD727_TORONTOWASHINGTON-DULLES_F2DYSY_21250507.pdf
# Pushing paper 2 - physical 12Jan2017.docx
# Pushing paper 2 - physical 12Jan2017.docx.gdoc
# RefLetter_Dr.E.Dolatabadi_VectorInstitute.docx
# RefLetter_Dr.E.Dolatabadi_VectorInstitute.docx.gdoc
# RERC: video analysis tool for usability and....gdoc
# Ryerson.txt
# Ryerson.zip
# SFU_CS_May2010.zip
# SOUND Sleep - a vision.gdoc
# SOUND Sleep - Funding Sources.gdoc
# Stereo Images.zip
# TRI Research Rounds - 2018 19.gsheet
# TRI - Vector Institute collaboration program.gdoc
# Tutorials to read watch.gdoc
# Untitled document.gdoc
# Untitled form.gform
# UOIT_Dec_2010 (1).7z
# UOIT_Dec_2010.7z
# VideoSegmentation_IdealMetric.gsheet
# window.jpg
# Work Experience at Feeling Software, Montreal, QC.gdoc
# Work Projects.gdoc
# Work_with_Josh.gdoc

# %%
# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
# Medium-FindFacesExample.ipynb	 OpenCV_GettingStarted.ipynb  Untitled1.ipynb
# OpenCV_GettingStarted (1).ipynb  Untitled0.ipynb

# %%
# install OpenCV
# !pip install opencv-python

# the usual ...
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import numpy as np
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (3.4.3.18)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.14.5)

# %%
# read an image (make sure CavePainting.jpg is in the main folder in your Google Drive)
img = cv2.imread('/content/drive/My Drive/CavePainting.jpg') # READS IN NUMPY ARRAY

# %%
whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# cv2        module     <module 'cv2.cv2' from '/<...>36m-x86_64-linux-gnu.so'>
# img        ndarray    453x676x3: 918684 elems, type `uint8`, 918684 bytes (897.15234375 kb)
# np         module     <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# plt        module     <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>

# %%
# not in
# cv2.imshow('image',img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# display the image
h,w = img.shape[:2]
print(img.shape)
plt.imshow(img,cmap='gray')
plt.show()
# what happened?
# Out:
# (453, 676, 3)

# %%
# BGR <--> RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# let's make a function
def imshowBGR2RGB( im ):
  img = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
  plt.imshow(im)
  plt.axis('off')
  return

# %%
imshowBGR2RGB(img)

# %%
# scaling 
rows, cols = img.shape[:2]
res = cv2.resize(img, (2*cols, 2*rows), interpolation = cv2.INTER_CUBIC)
imshowBGR2RGB(res)

# %%
# scaling 
res = cv2.resize(img,(400, 150), interpolation = cv2.INTER_CUBIC)
imshowBGR2RGB(res)

# %%
# rotate (centre, angle, scale)
M = cv2.getRotationMatrix2D((100, 120), -15, .7)
dst = cv2.warpAffine(img, M, (cols,rows))
imshowBGR2RGB(dst)

# %%
# affine transformation
pts1 = np.float32([[5,5],[5,50],[50,5]])
pts2 = np.float32([[10,3],[20,30],[40,6]])

M = cv2.getAffineTransform(pts1,pts2)

dst = cv2.warpAffine(img,M,(cols,rows))

imshowBGR2RGB(dst)

# %%
# perspective transformation

# getPerspectiveTransform

# how many point matches do we need?

# %%
# averaging

kernel = np.ones((7,7),np.float32)/49
dst = cv2.filter2D(img,-1,kernel)

imshowBGR2RGB(dst)

# %%
# compare with the original
imshowBGR2RGB(img)

# %%
# larger window
kernel = np.ones((15,15),np.float32)/225
dst = cv2.filter2D(img,-1,kernel)

imshowBGR2RGB(dst)

# %%
# Gaussian blur
kernel = cv2.getGaussianKernel(11, 3)

dst = cv2.filter2D(img,-1,kernel)

imshowBGR2RGB(dst)

# alternative: GaussianBlur(img,(15,15),20)

# %%
median = cv2.medianBlur(img, 7)
imshowBGR2RGB(median)

# %%
blur = cv2.bilateralFilter(img,15,75,75)
imshowBGR2RGB(blur)

# %%
# image gradients
img = cv2.imread('/content/drive/My Drive/window.jpg') # READS IN NUMPY ARRAY
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
laplacian = cv2.Laplacian(gray, cv2.CV_64F)
#imshowBGR2RGB(laplacian)


plt.subplot(2,1,1),plt.imshow(gray,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,1,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5,1,'Laplacian'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
median = cv2.medianBlur(gray, 5)
blur = cv2.GaussianBlur(gray,(5,5),1)
plt.imshow(blur, cmap = 'gray')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
# smooth first

laplacian = cv2.Laplacian(blur, cv2.CV_64F)

plt.subplot(2,1,1),plt.imshow(gray,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,1,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5,1,'Laplacian'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
sobelx = cv2.Sobel(blur, cv2.CV_64F, 1, 0, ksize=5)
sobely = cv2.Sobel(blur, cv2.CV_64F, 0, 1, ksize=5)

plt.subplot(2,1,1),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,1,2),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5,1,'Sobel Y'),
#  ([], <a list of 0 Text xticklabel objects>),
#  ([], <a list of 0 Text yticklabel objects>))

# %%
# edges (Canny)
edges = cv2.Canny(gray, 75, 100)

plt.subplot(1, 2, 1),plt.imshow(gray, cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2, 2),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4b2f1ec0b629> in <module>()
# ----> 1 edges = cv2.Canny(gray, 75, 100)
#       2
#       3 plt.subplot(1, 2, 1),plt.imshow(gray, cmap = 'gray')
#       4 plt.title('Original Image'), plt.xticks([]), plt.yticks([])
#       5 plt.subplot(1,2, 2),plt.imshow(edges,cmap = 'gray')
#
# NameError: name 'gray' is not defined

# %%
lowres = cv2.pyrDown(img)
lowres = cv2.pyrDown(lowres)
lowres = cv2.pyrDown(lowres)
imshowBGR2RGB(lowres)

# %%
highres = cv2.pyrUp(lowres)
highres = cv2.pyrUp(highres)
highres = cv2.pyrUp(highres)
imshowBGR2RGB(highres)

# %% [markdown]
# **more:** [OpenCV-Python Tutorials](https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_tutorials.html)
